# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# 'Colab Notebooks'   'My Drive'		      'Untitled folder'
#  cs		    'recordings senior year'   yolov3
# 'debate video.avi'  'shef ya basha.gdoc'      'yolov3 (1)'
# 'Google Earth'	    'SRS Samples.zip'

# %%
# %cd My Drive
# Out:
# /content/gdrive/My Drive

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10382, done.
# remote: Total 10382 (delta 0), reused 0 (delta 0), pack-reused 10382
# Receiving objects: 100% (10382/10382), 10.59 MiB | 7.57 MiB/s, done.
# Resolving deltas: 100% (7167/7167), done.

# %%
 # clone
#%cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-500e9b954a81> in <module>()
#       3 get_ipython().magic('pip install -qr requirements.txt  # install')
#       4
# ----> 5 import torch
#       6 from yolov5 import utils
#       7 display = utils.notebook_init()  # checks
#
# /usr/local/lib/python3.7/dist-packages/torch/__init__.py in <module>()
#     195     if USE_GLOBAL_DEPS:
#     196         _load_global_deps()
# --> 197     from torch._C import *  # noqa: F403
#     198
#     199 # Appease the type checker; ordinarily this binding is inserted by the
#
# RuntimeError: generic_type: cannot initialize type "TensorProtoDataType": an object with that name is already defined
